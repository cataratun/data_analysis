# %%
from google.colab import drive #importa o "conecta" con mi unidad de Drive
drive.mount('/content/drive')

import pandas as pd
nba = pd.read_excel('/content/drive/MyDrive/dataAnalysis/Nba Teams.xlsx')

nba.head()
#Imprime las primeras 5 filas del contenido
# Out:
# Mounted at /content/drive
#                 Name           Team   Division Position Height  Weight  \
# 0  Bogdan Bogdanovic  Atlanta Hawks  SouthEast        G    6'6   220.0
# 1    Brandon Goodwin  Atlanta Hawks  SouthEast        G    NaN   180.0
# 2     Bruno Fernando  Atlanta Hawks  SouthEast        F    6'9   240.0
# 3        Cam Reddish  Atlanta Hawks  SouthEast        F    6'8   218.0
# 4       Clint Capela  Atlanta Hawks  SouthEast        C   6'10   240.0
#
#   Birth_Date          College      Salary Country
# 0 1992-08-18              NaN  18000000.0      RS
# 1 1995-10-02  Central Florida   1701593.0      US
# 2 1998-08-15         Maryland   1517981.0      AO
# 3 1999-09-01             Duke         NaN      US
# 4 1994-05-18              NaN  16000000.0      CH

# %%
nba["Team"].value_counts()
#Devuelve el conteo de cada valor contenido en "Team" y el tipo de dato de la columna
# Out:
# Team
# Miami Heat                 18
# Boston Celtics             17
# Cleveland Cavaliers        17
# Indiana Pacers             17
# Detroit Pistons            17
# Brooklyn Nets              17
# New York Knicks            17
# Toronto Raptors            17
# Philadelphia 76ers         17
# Oklahoma City Thunder      17
# Milwaukee Bucks            17
# Minnesota Timberwolves     17
# Dallas Mavericks           17
# Houston Rockets            16
# Washington Wizards         16
# Orlando Magic              16
# Sacramento Kings           16
# Memphis Grizzlies          16
# Golden State Warriors      16
# Atlanta Hawks              16
# Charlotte Hornets          16
# Chicago Bulls              15
# Los Angeles Lakers         15
# Los Angeles Clippers       15
# Denver Nuggets             15
# New Orleans Pelicans       15
# San Antonio Spurs          15
# Phoenix Suns               15
# Utah Jazz                  15
# Portland Trail Blazers     14
# Name: count, dtype: int64

# %%
nba["Division"].value_counts()
  #Devuelve el conteo de valores contenidos en "Divisón"
#nba["Division"].value_counts(ascending = True)
  #Devuelve el conteo de valores contenidos en "División" en orden ascendente
# Out:
# Division
# Atlantic     85
# Central      83
# SouthEast    82
# SouthWest    79
# NorthWest    78
# Pacific      77
# Name: count, dtype: int64
