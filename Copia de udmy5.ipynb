# %%
from google.colab import drive #importa o "conecta" con mi unidad de Drive
drive.mount('/content/drive')

import pandas as pd
#Importa la librería para manipulación de datos y lo asigna a "pd" para practicidad

nba = pd.read_excel('/content/drive/MyDrive/dataAnalysis/Nba Teams.xlsx')
#Es necesario cambiar el método "_csv" a "_excel" ya que el documento del que sale la información está en dicho formato

nba.head()
#Imprime las primeras 5 líneas de la información
# Out:
# Mounted at /content/drive
#                 Name           Team   Division Position Height  Weight  \
# 0  Bogdan Bogdanovic  Atlanta Hawks  SouthEast        G    6'6   220.0
# 1    Brandon Goodwin  Atlanta Hawks  SouthEast        G    NaN   180.0
# 2     Bruno Fernando  Atlanta Hawks  SouthEast        F    6'9   240.0
# 3        Cam Reddish  Atlanta Hawks  SouthEast        F    6'8   218.0
# 4       Clint Capela  Atlanta Hawks  SouthEast        C   6'10   240.0
#
#   Birth_Date          College      Salary Country
# 0 1992-08-18              NaN  18000000.0      RS
# 1 1995-10-02  Central Florida   1701593.0      US
# 2 1998-08-15         Maryland   1517981.0      AO
# 3 1999-09-01             Duke         NaN      US
# 4 1994-05-18              NaN  16000000.0      CH

# %%
nba["Name"]
#Imprime solo los datos contenidos en "Name"
# Out:
# 0      Bogdan Bogdanovic
# 1        Brandon Goodwin
# 2         Bruno Fernando
# 3            Cam Reddish
# 4           Clint Capela
#              ...
# 493        Rui Hachimura
# 494                  NaN
# 495    Russell Westbrook
# 496        Thomas Bryant
# 497       Troy Brown Jr.
# Name: Name, Length: 498, dtype: object

# %%
nba["Salary"]
#Imprime solo los datos contenidos en "Salary"
# Out:
# 0      18000000.0
# 1       1701593.0
# 2       1517981.0
# 3             NaN
# 4      16000000.0
#           ...
# 493     4692840.0
# 494           NaN
# 495    41358814.0
# 496     8333333.0
# 497     3372840.0
# Name: Salary, Length: 498, dtype: float64

# %%
nba.Name
#Imprime solo la información contenida en "name"
# Out:
# 0      Bogdan Bogdanovic
# 1        Brandon Goodwin
# 2         Bruno Fernando
# 3            Cam Reddish
# 4           Clint Capela
#              ...
# 493        Rui Hachimura
# 494                  NaN
# 495    Russell Westbrook
# 496        Thomas Bryant
# 497       Troy Brown Jr.
# Name: Name, Length: 498, dtype: object
