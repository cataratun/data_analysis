# %%
from google.colab import drive #importa o "conecta" con mi unidad de Drive
drive.mount('/content/drive')

# !ls /content/drive/MyDrive #Indica las carpetas o posibles rutas de mi unidad
# Out:
# Mounted at /content/drive
# 'Calculo James Stewart 7 Edicion.pdf'
#  Certificado_RLCPD-CC79557896.pdf
#  Classroom
# 'Colab Notebooks'
#  dataAnalysis
# 'Informe Laboratorio.gdoc'
# 'Preguntas Trabajo'
# 'Trabajo Final Marketing - Propuesta Empresarial para Mejorar Desempleo en Sincelejo.gdoc'
#  Traiding
#  Tsuki

# %%
from google.colab import drive #importa o "conecta" con mi unidad de Drive
drive.mount('/content/drive')

import pandas as pd
#Importa la librería para manipulación de datos y lo asigna a "pd" para practicidad
pd.read_csv('/content/drive/MyDrive/dataAnalysis/Cities.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#               City     Country  Population
# 0           Kajuru    Botswana       21722
# 1             Leon       Spain        5629
# 2              Osh  kyrgyzstan        5679
# 3    Shumikhinskiy      Russia       10085
# 4         Bundoran     Ireland       23421
# ..             ...         ...         ...
# 596        Lobitos        Peru       10024
# 597         Bremen     Germany        5768
# 598         Harare    Zimbabwe       16679
# 599          Lagos     Nigeria       24800
# 600         Oshawa      Canada       13000
#
# [601 rows x 3 columns]

# %%
from google.colab import drive #importa o "conecta" con mi unidad de Drive
drive.mount('/content/drive')

import pandas as pd

countries = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv", usecols = ["Country"])
#Lee la información unicamente de la columna "Country" en el csv

pop = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv", usecols = ["Population"])
  #Igual que la anterior pero con la columna "Population"

pop.tail(10)
  #Muestra las últimas 10 filas

#countries.tail()
  #Muestra las últimas 5 filas por defecto de la información contenida
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      Population
# 591       11949
# 592        4114
# 593       16755
# 594       16325
# 595       16905
# 596       10024
# 597        5768
# 598       16679
# 599       24800
# 600       13000

# %%
from google.colab import drive #importa o "conecta" con mi unidad de Drive
drive.mount('/content/drive')

import pandas as pd

countries = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv", usecols = ["Country"])

countries.tail()
  #Imprime las últimas 5 filas de la columna "Country"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#       Country
# 596      Peru
# 597   Germany
# 598  Zimbabwe
# 599   Nigeria
# 600    Canada

# %%
from google.colab import drive #importa o "conecta" con mi unidad de Drive
drive.mount('/content/drive')

import pandas as pd

pop = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv", usecols = ["Population"])

pop.tail()
  #Muestra las últimas 5 filas de la columna "population"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      Population
# 596       10024
# 597        5768
# 598       16679
# 599       24800
# 600       13000

# %%
from google.colab import drive #importa o "conecta" con mi unidad de Drive
drive.mount('/content/drive')

import pandas as pd

pop = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv", usecols = ["Population"])

pop.head(2)
  #Imprime las primeras 2 filas contenidas en "Population"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Population
# 0       21722
# 1        5629

# %%
from google.colab import drive #importa o "conecta" con mi unidad de Drive
drive.mount('/content/drive')

import pandas as pd

countries = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv", usecols = ["Country"])

countries.count()
  #Cuenta el número de filas contenidas en "country" iniciando en 0
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Country    601
# dtype: int64

# %%
from google.colab import drive #importa o "conecta" con mi unidad de Drive
drive.mount('/content/drive')

import pandas as pd

pop = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv", usecols = ["Population"])

pop.count()
  #Cuenta el número de filas contenidas en "Population" iniciando en 0
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Population    601
# dtype: int64

# %%
from google.colab import drive #importa o "conecta" con mi unidad de Drive
drive.mount('/content/drive')

import pandas as pd

countries = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv", usecols = ["Country"])

countries.describe()
  #Cuenta las filas contenidas en "Country", la cantidad de valores únicos, el más repetido y la cantidad que el más frecuente aparece
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#           Country
# count         601
# unique        101
# top     Indonesia
# freq           86

# %%
from google.colab import drive #importa o "conecta" con mi unidad de Drive
drive.mount('/content/drive')

import pandas as pd

pop = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv", usecols = ["Population"])

pop.describe()
  #Total de filas o puntos de datos, no comienza desde 0, la media, la desviación estándar, el valor mínimo, el 25%, 50%, 75% y máximo
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#          Population
# count    601.000000
# mean   13932.415973
# std     6765.873291
# min     2528.000000
# 25%     7801.000000
# 50%    13966.000000
# 75%    19752.000000
# max    38745.000000

# %%
countries = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv", usecols=["City"])

# Orden ascendente alfabético por la columna "City"
countries_sorted = countries.sort_values(by="City")

# Orden descendente alfabético por la columna "City"
countries_sorted_desc = countries.sort_values(by="City", ascending=False)

#countries_sorted
countries_sorted_desc
# Out:
#               City
# 362           Zliv
# 538       Zhuoshui
# 427      Zhongxing
# 386  Zhongshangang
# 69   Zhongshangang
# ..             ...
# 467       Alcoutim
# 212       Alarobia
# 472          Aketi
# 66          Aizhai
# 581          Abuja
#
# [601 rows x 1 columns]

# %%
countries = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv", usecols = ["City"])
#Lee las filas contenidas en la columna "City"

countries.sort_values(by = ["City"], ascending = True, inplace = False)
#Organiza los valores contenidos en "City", puede ser en orden ascendente alfabético
#ascending (true: orden alfabético)
#inplace (true: devuelve la modificación del dataframe, no una nueva copia)

countries
# Out:
#               City
# 0           Kajuru
# 1             Leon
# 2              Osh
# 3    Shumikhinskiy
# 4         Bundoran
# ..             ...
# 596        Lobitos
# 597         Bremen
# 598         Harare
# 599          Lagos
# 600         Oshawa
#
# [601 rows x 1 columns]

# %%
cities = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv")
#No declara ninguna columna en específico

cities.sort_index(ascending = False, inplace = True)
#ascending(true: orden por posición)

cities
# Out:
#               City     Country  Population
# 600         Oshawa      Canada       13000
# 599          Lagos     Nigeria       24800
# 598         Harare    Zimbabwe       16679
# 597         Bremen     Germany        5768
# 596        Lobitos        Peru       10024
# ..             ...         ...         ...
# 4         Bundoran     Ireland       23421
# 3    Shumikhinskiy      Russia       10085
# 2              Osh  kyrgyzstan        5679
# 1             Leon       Spain        5629
# 0           Kajuru    Botswana       21722
#
# [601 rows x 3 columns]

# %%
print(cities)
#Imprime cities, y depende de la asignación en las líneas anteriores
# Out:
#               City     Country  Population
# 600         Oshawa      Canada       13000
# 599          Lagos     Nigeria       24800
# 598         Harare    Zimbabwe       16679
# 597         Bremen     Germany        5768
# 596        Lobitos        Peru       10024
# ..             ...         ...         ...
# 4         Bundoran     Ireland       23421
# 3    Shumikhinskiy      Russia       10085
# 2              Osh  kyrgyzstan        5679
# 1             Leon       Spain        5629
# 0           Kajuru    Botswana       21722
#
# [601 rows x 3 columns]

# %%
data = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv")
#asigna la lectura del dataframe a una nueva variable y la imprime

data
# Out:
#               City     Country  Population
# 0           Kajuru    Botswana       21722
# 1             Leon       Spain        5629
# 2              Osh  kyrgyzstan        5679
# 3    Shumikhinskiy      Russia       10085
# 4         Bundoran     Ireland       23421
# ..             ...         ...         ...
# 596        Lobitos        Peru       10024
# 597         Bremen     Germany        5768
# 598         Harare    Zimbabwe       16679
# 599          Lagos     Nigeria       24800
# 600         Oshawa      Canada       13000
#
# [601 rows x 3 columns]

# %%
#data = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv", index_col = ["City"])
  #Index_col dice qué columna usar como índice o referenica

#data = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv", usecols = ["City", "Country"], index_col = ["City"])
  #usecols declara qué columnas se leen, y "index_col" la columna de índice

data = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv")
data.head()
  #imprime únicamente las primeras 5 líneas por defecto
# Out:
#             City     Country  Population
# 0         Kajuru    Botswana       21722
# 1           Leon       Spain        5629
# 2            Osh  kyrgyzstan        5679
# 3  Shumikhinskiy      Russia       10085
# 4       Bundoran     Ireland       23421

# %%
data = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv")
city = data["City"]
#Asigna la lectura de únicamente una de las columnas

#city

city.get(3)
#Saca solo el contenido en la posición 3 de la columna declarada
# Out:
# 'Shumikhinskiy'

# %%
#cities = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv")
#cities.head()
  #Imprime los primeros 5 elementos contenidos en cities

data = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv")
poblacion = data["Population"]
  #Asigna la lectura de una sola de las columnas y lo imprime

print(poblacion)
# Out:
# 0      21722
# 1       5629
# 2       5679
# 3      10085
# 4      23421
#        ...
# 596    10024
# 597     5768
# 598    16679
# 599    24800
# 600    13000
# Name: Population, Length: 601, dtype: int64

# %%
cities = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv", usecols=["Country", "City"], index_col=["Country"])
cities.iloc[7]
  #Busca la posición indiciada en la columna declarada
#cities
# Out:
# City    Ondores
# Name: Peru, dtype: object

# %%
cities[0:4]
#Imprime desde la primera posición, hasta la segunda-1
# Out:
#                      City
# Country
# Botswana           Kajuru
# Spain                Leon
# kyrgyzstan            Osh
# Russia      Shumikhinskiy

# %%
cities[600:]
#Por defecto empieza desde la primera posición y termina en la última
# Out:
#            City
# Country
# Canada   Oshawa

# %%
cities[:600:100]
#desde donde: hasta donde: de a cuántos
# Out:
#                              City
# Country
# Botswana                   Kajuru
# Thailand                     Trat
# China                     Dingtou
# Indonesia                  Harian
# Portugal   Refojos de Riba de Ave
# Poland                  Zaleszany

# %%
#cities[-2:]
  #Imprime las últimas 2 filas, contando desde el final

cities[:-10:2]
  #imprime desde el principio hasta la final -10 líneas, de dos en dos
# Out:
#                       City
# Country
# Botswana            Kajuru
# kyrgyzstan             Osh
# Ireland           Bundoran
# Indonesia            Tutup
# Costa Rica         Heredia
# ...                    ...
# Indonesia        Bantawora
# China             Zhangcun
# Japan                 Guja
# Philippines       Consuelo
# Indonesia    Gemblengmulyo
#
# [296 rows x 1 columns]

# %%
from google.colab import drive #importa o "conecta" con mi unidad de Drive
drive.mount('/content/drive')

import pandas as pd

cities = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv")

#cities.iloc[2, 0]
  #Halla e imprime el valor en la coordenada indicada

cities.sort_values(by="Population")
  #Ordena ascendentemente a partir del argumento especificado
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                    City      Country  Population
# 67                Marco       Brazil        2528
# 245  Guadalupe Victoria       Mexico        2533
# 23           El Crucero    Nicaragua        2545
# 178           Bulalacao  Philippines        2568
# 322     Pantai Ceuremen    Indonesia        2574
# ..                  ...          ...         ...
# 29       Boca de Uchire    Venezuela       24943
# 444             Avignon       France       24958
# 513             Sembung    Indonesia       24989
# 184             Bagacay  Philippines       24995
# 16               Wufeng        China       38745
#
# [601 rows x 3 columns]

# %%
#city = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv", usecols = ["City", "Country"])
  #Lee las columnas especificadas

#city = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv", usecols = ["City", "Country"], index_col = "City")
  #Lee las columnas especificadas y asigna una de ellas como índice

city = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv")
city = city["Country"]
  #Asigna la lectura de la columna especificada a una nueva variable
city
# Out:
# 0        Botswana
# 1           Spain
# 2      kyrgyzstan
# 3          Russia
# 4         Ireland
#           ...
# 596          Peru
# 597       Germany
# 598      Zimbabwe
# 599       Nigeria
# 600        Canada
# Name: Country, Length: 601, dtype: object

# %%
city = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv")

city.iloc[0]
#Imprime los elementos en la posición 0 de todas las columnas si no se declara que lea solo una columna
# Out:
# City            Kajuru
# Country       Botswana
# Population       21722
# Name: 0, dtype: object

# %%
city = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv")
#Volvemos a establecer que city es la lectura de todas las columnas

city.set_index("City", inplace=True)
#Hacemos la columna "City" un índice para hacer buscas con mayor facilidad

city.loc["Lobitos"]
# Out:
#         Country  Population
# City
# Lobitos    Peru       22829
# Lobitos    Peru       10024

# %%
city = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv")
city.set_index("City", inplace=True)
city.loc["Kajuru"]
# Out:
# Country       Botswana
# Population       21722
# Name: Kajuru, dtype: object

# %%
city.sort_index(inplace = True, ascending = True)
#Ordena por índice, como anteriormente la ciudad fue declarada como índice, queda ordenado alfabéticamente
city
# Out:
#                                         Country  Population
# City
# Abuja                                   Nigeria       17400
# Aizhai                                    China       10173
# Aketi          Democratic Republic of the Congo       21555
# Alarobia                             Madagascar       17492
# Alcoutim                               Portugal       22000
# ...                                         ...         ...
# Zhongshangang                             China        3416
# Zhongshangang                             China       18425
# Zhongxing                                 China       13086
# Zhuoshui                                  China        6105
# Zliv                             Czech Republic       19686
#
# [601 rows x 2 columns]

# %%
city["Abuja":"Aketi"]
#imprime desde el ´rimer elemento declarado hasta el segundo
# Out:
#                                  Country  Population
# City
# Abuja                            Nigeria       17400
# Aizhai                             China       10173
# Aketi   Democratic Republic of the Congo       21555

# %%
city[:"Bremen"]
#Imprime desde el inicio hasta el elemento declarado
# Out:
#                                     Country  Population
# City
# Abuja                               Nigeria       17400
# Aizhai                                China       10173
# Aketi      Democratic Republic of the Congo       21555
# Alarobia                         Madagascar       17492
# Alcoutim                           Portugal       22000
# ...                                     ...         ...
# Bolgar                               Russia        5532
# Bomomani                          Indonesia       24722
# Bonavista                            Canada       22001
# Bradag                            Indonesia       12186
# Bremen                              Germany        5768
#
# [84 rows x 2 columns]

# %%
city.set_index("City", inplace=True)
#Establece la ciudad como índice para realizar búsquedas con mayor facilidad

city.loc[["Bolgar", "Abuja", "Osh"]]
# Out:
#         index     Country  Population
# City
# Bolgar     74      Russia        5532
# Abuja     581     Nigeria       17400
# Osh         2  kyrgyzstan        5679

# %%
city.head(-10)
#Muestra todas las líneas excepto las últimas 10
# Out:
#                  index      Country  Population
# City
# Kajuru               0     Botswana       21722
# Leon                 1        Spain        5629
# Osh                  2   kyrgyzstan        5679
# Shumikhinskiy        3       Russia       10085
# Bundoran             4      Ireland       23421
# ...                ...          ...         ...
# Guja               586        Japan       18843
# Caijiagang         587        China       21704
# Consuelo           588  Philippines       11094
# Santa Magdalena    589  Philippines        3803
# Gemblengmulyo      590    Indonesia       23737
#
# [591 rows x 3 columns]

# %%
city["Abuja": "Santa Magdalena": 2]
#Imprime desde el primer elemento hasta el segundo de a 2 "pasos"
# Out:
#                  index      Country  Population
# City
# Abuja              581      Nigeria       17400
# Waihai             583        China       24751
# Plaeng Yao         585     Thailand        6055
# Caijiagang         587        China       21704
# Santa Magdalena    589  Philippines        3803

# %%
data = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv", usecols = ["City", "Country"], index_col = "City")
  #Ordena por la columna "ciudad" porque la establecimos como índice

#data = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv", usecols = ["City", "Country"])
  #Ordena por índice por defecto ya que no se modificó

data.sort_index(inplace = True)
data
# Out:
#                                         Country
# City
# Abuja                                   Nigeria
# Aizhai                                    China
# Aketi          Democratic Republic of the Congo
# Alarobia                             Madagascar
# Alcoutim                               Portugal
# ...                                         ...
# Zhongshangang                             China
# Zhongshangang                             China
# Zhongxing                                 China
# Zhuoshui                                  China
# Zliv                             Czech Republic
#
# [601 rows x 1 columns]

# %%
city = data["City"]
#Imprime solo los elementos de la columna "city"
city
# Out:
# 0             Kajuru
# 1               Leon
# 2                Osh
# 3      Shumikhinskiy
# 4           Bundoran
#            ...
# 596          Lobitos
# 597           Bremen
# 598           Harare
# 599            Lagos
# 600           Oshawa
# Name: City, Length: 601, dtype: object

# %%
city.get(4)
#Imprime el elemento en esa posición, y como anteriormente se le dijo que solo de la columna "City", solo imprime uno
# Out:
# 'Bundoran'

# %%
city.get([1, 5])
#Imprime los elementos en las posiciones declaradas
# Out:
# 1         Leon
# 5    La Paloma
# Name: City, dtype: object

# %%
city = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv")
city.set_index("City", inplace=True)

city.loc["Alis"]
#city.loc["Leon"]
  #No puede buscar dos elementos si no es por su posición, así que hay que separarlos
# Out:
# Country        Peru
# Population    13603
# Name: Alis, dtype: object

# %%
city = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv")
print(city.get("City"))
#Busca columnas por el nombre, si no existe una columna con la orden buscada, no hay tal columna
# Out:
# 0             Kajuru
# 1               Leon
# 2                Osh
# 3      Shumikhinskiy
# 4           Bundoran
#            ...
# 596          Lobitos
# 597           Bremen
# 598           Harare
# 599            Lagos
# 600           Oshawa
# Name: City, Length: 601, dtype: object

# %%
city.dtypes
#Muestra los tipos de datos de cada columna
# Out:
# City          object
# Country       object
# Population     int64
# dtype: object

# %%
city.values
#Devuelve los valores ordenados en listas, sin nombres de columnas o índices
# Out:
# array([['Kajuru', 'Botswana', 21722],
#        ['Leon', 'Spain', 5629],
#        ['Osh', 'kyrgyzstan', 5679],
#        ...,
#        ['Harare', 'Zimbabwe', 16679],
#        ['Lagos', 'Nigeria', 24800],
#        ['Oshawa', 'Canada', 13000]], dtype=object)

# %%
population = pop
#Asigna la variable a la lectura de únicamente la columna "Population"
population
# Out:
#      Population
# 0         21722
# 1          5629
# 2          5679
# 3         10085
# 4         23421
# ..          ...
# 596       10024
# 597        5768
# 598       16679
# 599       24800
# 600       13000
#
# [601 rows x 1 columns]

# %%
population = pop["Population"]
population
#Lo mismo
# Out:
# 0      21722
# 1       5629
# 2       5679
# 3      10085
# 4      23421
#        ...
# 596    10024
# 597     5768
# 598    16679
# 599    24800
# 600    13000
# Name: Population, Length: 601, dtype: int64

# %%
population.dtypes
#No lleva paréntesis "population.dtypes()"
# Out:
# dtype('int64')

# %%
#pop.values
  #Devuelve los valores contenidos en la columna como listas "[]"
#population.values
  #Devuelve los valores contenidos en la columna como csv ","
population.describe()
  #Devuelve el conteo total de los elementos, la media, la desviación estándar, mínimo, 25%, 50%, 75% y máxima
# Out:
# count      601.000000
# mean     13932.415973
# std       6765.873291
# min       2528.000000
# 25%       7801.000000
# 50%      13966.000000
# 75%      19752.000000
# max      38745.000000
# Name: Population, dtype: float64

# %%
city.index
#Devuelve el rango de los índices de "city", diciendo dónde comienza, termina y de a cuántos cuenta
# Out:
# RangeIndex(start=0, stop=601, step=1)

# %%
population.index
#Devuelve el rango de los índices de "population", diciendo dónde comienza, termina y de a cuántos cuenta
# Out:
# RangeIndex(start=0, stop=601, step=1)

# %%
city = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv")
city.set_index("City", inplace=True)
city.index.is_unique
#Devuelve un booleano para saber si el índice es único o no
# Out:
# False

# %%
population = pd.read_csv("/content/drive/MyDrive/dataAnalysis/Cities.csv")
population.set_index("Population", inplace=True)
population.index.is_unique
# Out:
# False

# %%
city.ndim
#Número de dimensiones
# Out:
# 2

# %%
pop.ndim
#population.ndim
# Out:
# 2
