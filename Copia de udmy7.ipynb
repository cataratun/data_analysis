# %%
from google.colab import drive #importa o "conecta" con mi unidad de Drive
drive.mount('/content/drive')

import pandas as pd
nba = pd.read_excel("/content/drive/MyDrive/dataAnalysis/Nba Teams.xlsx")
nba.head()
#Imprime las primeras 5 líneas
# Out:
# Mounted at /content/drive
#                 Name           Team   Division Position Height  Weight  \
# 0  Bogdan Bogdanovic  Atlanta Hawks  SouthEast        G    6'6   220.0
# 1    Brandon Goodwin  Atlanta Hawks  SouthEast        G    NaN   180.0
# 2     Bruno Fernando  Atlanta Hawks  SouthEast        F    6'9   240.0
# 3        Cam Reddish  Atlanta Hawks  SouthEast        F    6'8   218.0
# 4       Clint Capela  Atlanta Hawks  SouthEast        C   6'10   240.0
#
#   Birth_Date          College      Salary Country
# 0 1992-08-18              NaN  18000000.0      RS
# 1 1995-10-02  Central Florida   1701593.0      US
# 2 1998-08-15         Maryland   1517981.0      AO
# 3 1999-09-01             Duke         NaN      US
# 4 1994-05-18              NaN  16000000.0      CH

# %%
nba["Teams"] = " ahora ves qué hace "
#Cambia la información contenida en la columna indicada (la misma en cada fila)

nba["nba Teams"] = " "
nba.head()
#Imprime las primeras 5 líneas del contenido
# Out:
#                 Name           Team   Division Position Height  Weight  \
# 0  Bogdan Bogdanovic  Atlanta Hawks  SouthEast        G    6'6   220.0
# 1    Brandon Goodwin  Atlanta Hawks  SouthEast        G    NaN   180.0
# 2     Bruno Fernando  Atlanta Hawks  SouthEast        F    6'9   240.0
# 3        Cam Reddish  Atlanta Hawks  SouthEast        F    6'8   218.0
# 4       Clint Capela  Atlanta Hawks  SouthEast        C   6'10   240.0
#
#   Birth_Date          College      Salary Country                 Teams  \
# 0 1992-08-18              NaN  18000000.0      RS   ahora ves qué hace
# 1 1995-10-02  Central Florida   1701593.0      US   ahora ves qué hace
# 2 1998-08-15         Maryland   1517981.0      AO   ahora ves qué hace
# 3 1999-09-01             Duke         NaN      US   ahora ves qué hace
# 4 1994-05-18              NaN  16000000.0      CH   ahora ves qué hace
#
#   nba Teams
# 0
# 1
# 2
# 3
# 4

# %%
#nba.Name
  #Imprime solo la columna Name

#nba["nba Teams"]
  #Imprime solo la columna nba Teams, al haber un espacio en el nombre de la columna, se debe cambiar el método y usar corchetes y comillas

#nba.Teams
  #Imprime solo la columna Teams

#nba.Sports
  #Marca un error en caso de que no exista una columna con el nombre escrito

# %%
nba["Sports"] = "basket"
#Reasigna el valor contenido en Sports por el indicado

nba.head()
# Out:
#                 Name           Team   Division Position Height  Weight  \
# 0  Bogdan Bogdanovic  Atlanta Hawks  SouthEast        G    6'6   220.0
# 1    Brandon Goodwin  Atlanta Hawks  SouthEast        G    NaN   180.0
# 2     Bruno Fernando  Atlanta Hawks  SouthEast        F    6'9   240.0
# 3        Cam Reddish  Atlanta Hawks  SouthEast        F    6'8   218.0
# 4       Clint Capela  Atlanta Hawks  SouthEast        C   6'10   240.0
#
#   Birth_Date          College      Salary Country                 Teams  \
# 0 1992-08-18              NaN  18000000.0      RS   ahora ves qué hace
# 1 1995-10-02  Central Florida   1701593.0      US   ahora ves qué hace
# 2 1998-08-15         Maryland   1517981.0      AO   ahora ves qué hace
# 3 1999-09-01             Duke         NaN      US   ahora ves qué hace
# 4 1994-05-18              NaN  16000000.0      CH   ahora ves qué hace
#
#   nba Teams  Sports
# 0            basket
# 1            basket
# 2            basket
# 3            basket
# ...

# %%
#nba

#nba.drop("Team", axis = 1, inplace = True)
"""
  Elimina la columna Team
  axis=1 - elimina columnas, axis=0 - elimina filas
  inplace=true - modifica el dataframe original
"""
#nba.insert(3, column = "Winners", value = "Colombians")
"""
  Inserta una columna en la posición tal
  dice el nombre de la columna a agregar
  dice el valor que tendrá
"""
nba.insert(2, column = "Director", value = "Turmequé")
nba
# Out:
#                   Name   Division  Director   Sportss       Teams     Winners  \
# 0    Bogdan Bogdanovic  SouthEast  Turmequé  Turmequé  Colombians  Colombians
# 1      Brandon Goodwin  SouthEast  Turmequé  Turmequé  Colombians  Colombians
# 2       Bruno Fernando  SouthEast  Turmequé  Turmequé  Colombians  Colombians
# 3          Cam Reddish  SouthEast  Turmequé  Turmequé  Colombians  Colombians
# 4         Clint Capela  SouthEast  Turmequé  Turmequé  Colombians  Colombians
# ..                 ...        ...       ...       ...         ...         ...
# 493      Rui Hachimura  SouthEast  Turmequé  Turmequé  Colombians  Colombians
# 494                NaN        NaN  Turmequé  Turmequé  Colombians  Colombians
# 495  Russell Westbrook  SouthEast  Turmequé  Turmequé  Colombians  Colombians
# 496      Thomas Bryant  SouthEast  Turmequé  Turmequé  Colombians  Colombians
# 497     Troy Brown Jr.  SouthEast  Turmequé  Turmequé  Colombians  Colombians
#
# ...

# %%
nba
#Imprime la versión modificada del dataframe
# Out:
#                   Name   Division  Director   Sportss       Teams     Winners  \
# 0    Bogdan Bogdanovic  SouthEast  Turmequé  Turmequé  Colombians  Colombians
# 1      Brandon Goodwin  SouthEast  Turmequé  Turmequé  Colombians  Colombians
# 2       Bruno Fernando  SouthEast  Turmequé  Turmequé  Colombians  Colombians
# 3          Cam Reddish  SouthEast  Turmequé  Turmequé  Colombians  Colombians
# 4         Clint Capela  SouthEast  Turmequé  Turmequé  Colombians  Colombians
# ..                 ...        ...       ...       ...         ...         ...
# 493      Rui Hachimura  SouthEast  Turmequé  Turmequé  Colombians  Colombians
# 494                NaN        NaN  Turmequé  Turmequé  Colombians  Colombians
# 495  Russell Westbrook  SouthEast  Turmequé  Turmequé  Colombians  Colombians
# 496      Thomas Bryant  SouthEast  Turmequé  Turmequé  Colombians  Colombians
# 497     Troy Brown Jr.  SouthEast  Turmequé  Turmequé  Colombians  Colombians
#
# ...

# %%
nba.insert(2, column = "El más grande", value = "Millos")
#inserta una columna en la posición indicada y el nombre dado con el mismo valor en cada posición
nba
# Out:
#                   Name                Team El más grande   Division Position  \
# 0    Bogdan Bogdanovic       Atlanta Hawks        Millos  SouthEast        G
# 1      Brandon Goodwin       Atlanta Hawks        Millos  SouthEast        G
# 2       Bruno Fernando       Atlanta Hawks        Millos  SouthEast        F
# 3          Cam Reddish       Atlanta Hawks        Millos  SouthEast        F
# 4         Clint Capela       Atlanta Hawks        Millos  SouthEast        C
# ..                 ...                 ...           ...        ...      ...
# 493      Rui Hachimura  Washington Wizards        Millos  SouthEast        F
# 494                NaN                 NaN        Millos        NaN      NaN
# 495  Russell Westbrook  Washington Wizards        Millos  SouthEast        G
# 496      Thomas Bryant  Washington Wizards        Millos  SouthEast        C
# 497     Troy Brown Jr.  Washington Wizards        Millos  SouthEast      G-F
#
# ...

# %%
nba
#Imprime la última versión de modificaciones del dataframe
# Out:
#                   Name   Division El más grande     Equipos  Director  \
# 0    Bogdan Bogdanovic  SouthEast        Millos  Colombians  Turmequé
# 1      Brandon Goodwin  SouthEast        Millos  Colombians  Turmequé
# 2       Bruno Fernando  SouthEast        Millos  Colombians  Turmequé
# 3          Cam Reddish  SouthEast        Millos  Colombians  Turmequé
# 4         Clint Capela  SouthEast        Millos  Colombians  Turmequé
# ..                 ...        ...           ...         ...       ...
# 493      Rui Hachimura  SouthEast        Millos  Colombians  Turmequé
# 494                NaN        NaN        Millos  Colombians  Turmequé
# 495  Russell Westbrook  SouthEast        Millos  Colombians  Turmequé
# 496      Thomas Bryant  SouthEast        Millos  Colombians  Turmequé
# 497     Troy Brown Jr.  SouthEast        Millos  Colombians  Turmequé
#
#       Sportss       Teams     Winners Position Height  Weight Birth_Date  \
# ...
