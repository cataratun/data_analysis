# %%
import pandas as pd

# %%
data = {"name": ["Sally", "Jhon", "Kim"], "age": [4, 6 ,7], "gender": ["female", "male", "male"]}
#Crea una variable data que se compone de un diccionario con información

# %%
data_imp = pd.DataFrame(data)
data_imp
#Asigna la lectura del diccionario a una variable
# Out:
#     name  age  gender
# 0  Sally    4  female
# 1   Jhon    6    male
# 2    Kim    7    male

# %%
data_ind = pd.DataFrame(data, index = ["Kid1", "Kid2", "Kid3"])
data_ind
#Asigna la lectura del diccionario a una variable y le cambia los nombres a los índices
# Out:
#        name  age  gender
# Kid1  Sally    4  female
# Kid2   Jhon    6    male
# Kid3    Kim    7    male
