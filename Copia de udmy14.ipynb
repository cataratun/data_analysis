# %%
from google.colab import drive #importa o "conecta" con mi unidad de Drive
drive.mount('/content/drive')

import pandas as pd
nba = pd.read_excel('/content/drive/MyDrive/dataAnalysis/Nba Teams.xlsx')

nba.head()
#Imprime las primeras 5 filas del contenido
# Out:
# Mounted at /content/drive
#                 Name           Team   Division Position Height  Weight  \
# 0  Bogdan Bogdanovic  Atlanta Hawks  SouthEast        G    6'6   220.0
# 1    Brandon Goodwin  Atlanta Hawks  SouthEast        G    NaN   180.0
# 2     Bruno Fernando  Atlanta Hawks  SouthEast        F    6'9   240.0
# 3        Cam Reddish  Atlanta Hawks  SouthEast        F    6'8   218.0
# 4       Clint Capela  Atlanta Hawks  SouthEast        C   6'10   240.0
#
#   Birth_Date          College      Salary Country
# 0 1992-08-18              NaN  18000000.0      RS
# 1 1995-10-02  Central Florida   1701593.0      US
# 2 1998-08-15         Maryland   1517981.0      AO
# 3 1999-09-01             Duke         NaN      US
# 4 1994-05-18              NaN  16000000.0      CH

# %%
nba.sort_values("Name").head(20)
#Ordena el contenido por orden alfabético ya que asume la columna "Name" como índice e imprime las primeras 20 filas
# Out:
#                    Name                     Team   Division Position Height  \
# 354        Aaron Gordon            Orlando Magic  SouthEast        F    6'8
# 186       Aaron Holiday           Indiana Pacers    Central        G    NaN
# 18        Aaron Nesmith           Boston Celtics   Atlantic      G-F    6'6
# 388         Abdel Nader             Phoenix Suns    Pacific        F    6'5
# 70        Adam Mokoka              Chicago Bulls    Central        G    6'5
# 337          Al Horford    Oklahoma City Thunder  NorthWest      C-F    6'9
# 355     Al-Farouq Aminu            Orlando Magic  SouthEast        F    6'8
# 319          Alec Burks          New York Knicks   Atlantic        G    6'6
# 338  Aleksej Pokusevski    Oklahoma City Thunder  NorthWest        F   6'11
# 219         Alex Caruso       Los Angeles Lakers    Pacific        G    6'5
# 449            Alex Len          Toronto Raptors   Atlantic        C    7'0
# ...

# %%
#nba.sort_values("Salary")
  #Ordena los valores contenidos en "Salary"

import pandas as pd
nba = pd.read_excel('/content/drive/MyDrive/dataAnalysis/Nba Teams.xlsx')
nba.dropna(inplace=True)
  #Elimina llos valores nulos dentro del contenido
#nba

nba = nba.sort_values("Salary", ascending = True)
  #Ordena los valores contenidos en "Salary"
nba
# Out:
#                        Name                   Team   Division Position Height  \
# 248        Sean McDermott        Memphis Grizzlies  SouthWest        F    6'6
# 254            Breein Tyree             Miami Heat  SouthEast        G    6'2
# 225  Kostas Antetokounmpo       Los Angeles Lakers    Pacific        F   6'10
# 245        Killian Tillie        Memphis Grizzlies  SouthWest        F   6'10
# 350          Omer Yurtseven  Oklahoma City Thunder  NorthWest        C    7'0
# ..                      ...                    ...        ...      ...    ...
# 180            James Harden        Houston Rockets  SouthWest        G    6'5
# 181               John Wall        Houston Rockets  SouthWest        G    6'4
# 495       Russell Westbrook     Washington Wizards  SouthEast        G    6'3
# 391              Chris Paul           Phoenix Suns    Pacific        G    6'1
# 168           Stephen Curry  Golden State Warriors    Pacific        G    6'3
#
# ...

# %%
#nba.sort_values(["Team", "Name"])
  #Ordena los valores contenidos en "Team" y "Name"
nba.sort_values(["Team", "Name"], na_position = 'first')
  #Coloca los valores nulos al principio del contenido, sin embargo como en el código anterior se eliminaron los valores nulos no se ve
# Out:
#                   Name                Team   Division Position Height  Weight  \
# 2       Bruno Fernando       Atlanta Hawks  SouthEast        F    6'9   240.0
# 6      De'Andre Hunter       Atlanta Hawks  SouthEast        F    6'7   225.0
# 7         John Collins       Atlanta Hawks  SouthEast        F    6'9   235.0
# 8        Kevin Huerter       Atlanta Hawks  SouthEast        G    6'7   190.0
# 10           Kris Dunn       Atlanta Hawks  SouthEast        G    6'3   205.0
# ..                 ...                 ...        ...      ...    ...     ...
# 492        Robin Lopez  Washington Wizards  SouthEast        C    7'0   281.0
# 493      Rui Hachimura  Washington Wizards  SouthEast        F    6'8   230.0
# 495  Russell Westbrook  Washington Wizards  SouthEast        G    6'3   200.0
# 496      Thomas Bryant  Washington Wizards  SouthEast        C   6'10   248.0
# 497     Troy Brown Jr.  Washington Wizards  SouthEast      G-F    6'6   215.0
#
# ...
